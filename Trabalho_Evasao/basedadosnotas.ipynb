# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ## Reading the spreadsheet

# %%
excel_path = "BaseDadosNotas.xlsx"
df = pd.read_excel(excel_path)
df.head()
# Out:
#          ID  PROVA1  PROVA2  TRABALHO   SITUAÇÃO
# 0  a1902_01     2.0     1.5       0.5  Reprovado
# 1  a1902_02     8.0     4.8       8.8   Aprovado
# 2  a1902_03     3.0     0.0       1.8  Reprovado
# 3  a1902_04     8.0     7.5       2.3   Aprovado
# 4  a1902_05     2.5     0.0       1.2  Reprovado

# %% [markdown]
# ## Feature Engineering

# %%
# Separar as features
X = df[['PROVA1', 'PROVA2', 'TRABALHO']]  # define as entradas
y = df['SITUAÇÃO'].map({'Aprovado': 1, 'Reprovado': 0})  # define as saidas (boolean)

# divide os dados (148 para treino, 73 para teste)
X_train, X_test = X.iloc[:148], X.iloc[148:]
y_train, y_test = y.iloc[:148], y.iloc[148:]

# Converte os dados para tensores do tipo float para as features
X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test.values, dtype=torch.float32)

# Converte os targets para tensores (pode ser float para a função BCELoss)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)

# %%
class Perceptron(nn.Module):
    def __init__(self, input_size, peso, bias, use_bias):
        super(Perceptron, self).__init__()
        self.fc = nn.Linear(input_size, 1, bias=use_bias)      # Camada linear: transforma entrada em saída

        '''
        # Definir pesos e viés iniciais
        with torch.no_grad():
            self.fc.weight.fill_(peso)      # Define o peso
            if use_bias:
                self.fc.bias.fill_(bias)        # Define o viés
        #OBS: o peso e o bias são definidos aleatóriamente ao iniciar nn.Linear
        '''

    #A função forward define o que acontece quando os dados passam pelo modelo, ou seja, como a entrada é transformada em saída.
    def forward(self, x):
        return torch.sigmoid(self.fc(x))                    # Usa a função sigmoide para limitar a saída entre 0 e 1

# %%
# Rede 3 neuronios
class RedeNeural:
    def __init__(self):
        input_size = 3
        peso = 0.5
        bias = 0.5
        use_bias = True

        self.perceptron_entrada1 = Perceptron(input_size, peso, bias, use_bias)
        self.perceptron_entrada2 = Perceptron(input_size, peso, bias, use_bias)
        self.perceptron_entrada3 = Perceptron(input_size, peso, bias, use_bias)
        self.perceptron_saida1 = Perceptron(3, peso, bias, use_bias)

        lr = 0.5
        self.criterion = nn.BCELoss()
        self.optimizer_entrada1 = optim.SGD(self.perceptron_entrada1.parameters(), lr)
        self.optimizer_entrada2 = optim.SGD(self.perceptron_entrada2.parameters(), lr)
        self.optimizer_entrada3 = optim.SGD(self.perceptron_entrada3.parameters(), lr)
        self.optimizer_saida1 = optim.SGD(self.perceptron_saida1.parameters(), lr)

    def treinamento(self, epocas):
        for epoch in range(epocas):
            self.optimizer_entrada1.zero_grad()
            self.optimizer_entrada2.zero_grad()
            self.optimizer_entrada3.zero_grad()
            self.optimizer_saida1.zero_grad()

            output_1 = self.perceptron_entrada1(X_train_tensor)
            output_2 = self.perceptron_entrada2(X_train_tensor)
            output_3 = self.perceptron_entrada3(X_train_tensor)

            combined = torch.cat((output_1, output_2, output_3), dim=1)
            output_final = self.perceptron_saida1(combined)
            loss_final = self.criterion(output_final, y_train_tensor)
            loss_total = loss_final
            loss_total.backward()

            self.optimizer_entrada1.step()
            self.optimizer_entrada2.step()
            self.optimizer_entrada3.step()
            self.optimizer_saida1.step()

    def teste(self):
        with torch.no_grad():
            output_1 = self.perceptron_entrada1(X_test_tensor)
            output_2 = self.perceptron_entrada2(X_test_tensor)
            output_3 = self.perceptron_entrada3(X_test_tensor)
            output_final = self.perceptron_saida1(torch.cat((output_1, output_2, output_3), dim=1))
        saida_binaria = (output_final >= 0.5).float()
        return saida_binaria, output_final

# %%
class RedeNeuralMLP2:

    def __init__(self):
        # Inicializar o Perceptron
        input_size = 3                         #número de neurônios de entrada (prova1, 2 e trabalho)

        #define os valores iniciais das variáveis
        peso = 0.5
        bias = 0.5
        use_bias = True


        # cria os perceptrons de entrada (camada oculta)
        self.perceptron_entrada1 = Perceptron(input_size, peso, bias, use_bias)
        self.perceptron_entrada2 = Perceptron(input_size, peso, bias, use_bias)
        #self.perceptron_entrada3 = Perceptron(input_size, peso, bias, use_bias)
        # perceptron de saida
        self.perceptron_saida1 = Perceptron(2, peso, bias, use_bias)    #input_size deve ser 2 pois ele receberá as saídas de ambos os neurônios anteriores

        #taxa de aprendizagem
        lr = 0.5

        # Função de perda e otimizador
        self.criterion = nn.BCELoss()                        #Serve para calcular a função de erro(loss) para o backpropagation

        #servem para atualizar os pesos (otimizar)
        self.optimizer_entrada1 = optim.SGD(self.perceptron_entrada1.parameters(), lr)   # Gradiente descendente estocástico
        self.optimizer_entrada2 = optim.SGD(self.perceptron_entrada2.parameters(), lr)   # Gradiente descendente estocástico
        #self.optimizer_entrada3 = optim.SGD(self.perceptron_entrada3.parameters(), lr)  # Gradiente descendente estocástico
        self.optimizer_saida1 = optim.SGD(self.perceptron_saida1.parameters(), lr)   # Gradiente descendente estocástico

    def treinamento(self, epocas):
        for epoch in range(epocas):
            # Zera os gradientes para todas as partes da rede
            self.optimizer_entrada1.zero_grad()
            self.optimizer_entrada2.zero_grad()
            self.optimizer_saida1.zero_grad()

            # Passagem forward dos perceptrons de entrada
            output_1 = self.perceptron_entrada1(X_train_tensor)
            output_2 = self.perceptron_entrada2(X_train_tensor)

            # Calcula as perdas individuais para as camadas de entrada
            #loss1 = self.criterion(output_1, y_train_tensor)
            #loss2 = self.criterion(output_2, y_train_tensor)

            # Faz com que o neurônio de saída receba ambas as entradas separadamente, a fim de poder pondera-las corretamente
            combined = torch.cat((output_1, output_2), dim=1)
            output_final = self.perceptron_saida1(combined)
            #output_final = self.perceptron_saida1((output_1 + output_2) / 2)
            loss_final = self.criterion(output_final, y_train_tensor)

            # Soma todas as perdas para formar a perda total
            loss_total = loss_final

            # Realiza a retropropagação de uma única vez
            loss_total.backward()

            # Atualiza os pesos
            self.optimizer_entrada1.step()
            self.optimizer_entrada2.step()
            self.optimizer_saida1.step()

            # Opcional: imprimir os losses para monitorar o treinamento
            if (epoch + 1) % 10 == 0:
                print(
                    f"Época {epoch + 1}/{epocas}, Loss final: {loss_final.item():.4f}"
                )

    def teste(self):
        # Desativa o cálculo de gradientes para avaliação
        with torch.no_grad():
            output_1 = self.perceptron_entrada1(X_test_tensor)
            output_2 = self.perceptron_entrada2(X_test_tensor)
            output_final = self.perceptron_saida1(torch.cat((output_1, output_2), dim=1))

        # Aplica threshold 0.5 para converter probabilidades em classe binária
        saida_binaria = (output_final >= 0.5).float()
        return saida_binaria, output_final

# %%
def predict(rn):
    rn.treinamento(epocas)
    y_pred_bin, y_pred_prob = rn.teste()
    pred_bin_np = y_pred_bin.squeeze().numpy()
    pred_prob_np = y_pred_prob.squeeze().numpy()
    y_true_np = y_test_tensor.squeeze().numpy()
    acertou = (pred_bin_np == y_true_np)
    acertos = acertou.sum()
    total = len(acertou)
    taxa_acerto = acertos / total
    return [epocas, i + 1, acertos, total, taxa_acerto]

# %%
resultados = []

for epocas in [30, 50, 100]:
    for i in range(50):
        rn_3neuronios = RedeNeural()
        resultado = predict(rn_3neuronios)
        resultados.append(resultado)


df_resultados = pd.DataFrame(resultados, columns=["Épocas", "Execução", "Acertos", "Total", "Taxa de Acerto"])
df_resultados.to_csv("resultados.csv", sep="\t", index=False)
df_resultados.to_excel("resultados.xlsx", index=False)
estatisticas = df_resultados.groupby("Épocas")["Taxa de Acerto"].describe()
estatisticas.to_excel("analise_estatistica.xlsx")
estatisticas
# Out:
#         count      mean       std       min       25%       50%       75%  \
# Épocas
# 30       50.0  0.670411  0.017593  0.657534  0.657534  0.657534  0.671233
# 50       50.0  0.704384  0.036725  0.657534  0.671233  0.712329  0.739726
# 100      50.0  0.741918  0.005073  0.739726  0.739726  0.739726  0.739726
#
#              max
# Épocas
# 30      0.726027
# 50      0.753425
# 100     0.753425

# %%
resultados2 = []

for epocas in [30, 50, 100]:
    for i in range(50):
        rn_MLP2 = RedeNeuralMLP2()
        resultado = predict(rn_MLP2)
        resultados2.append(resultado)


df_resultados2 = pd.DataFrame(resultados2, columns=["Épocas", "Execução", "Acertos", "Total", "Taxa de Acerto"])
df_resultados2.to_csv("resultados2.csv", sep="\t", index=False)
df_resultados2.to_excel("resultados2.xlsx", index=False)
estatisticas2 = df_resultados2.groupby("Épocas")["Taxa de Acerto"].describe()
estatisticas2.to_excel("analise_estatistica2.xlsx")
estatisticas2
# Out:
# Época 10/30, Loss final: 0.5637
# Época 20/30, Loss final: 0.5375
# Época 30/30, Loss final: 0.4984
# Época 10/30, Loss final: 0.5515
# Época 20/30, Loss final: 0.5302
# Época 30/30, Loss final: 0.5028
# Época 10/30, Loss final: 0.5905
# Época 20/30, Loss final: 0.5857
# Época 30/30, Loss final: 0.5740
# Época 10/30, Loss final: 0.5988
# Época 20/30, Loss final: 0.5905
# Época 30/30, Loss final: 0.5853
# Época 10/30, Loss final: 0.5970
# Época 20/30, Loss final: 0.5810
# Época 30/30, Loss final: 0.5650
# Época 10/30, Loss final: 0.6053
# Época 20/30, Loss final: 0.5613
# Época 30/30, Loss final: 0.5318
# Época 10/30, Loss final: 0.5815
# Época 20/30, Loss final: 0.5259
# Época 30/30, Loss final: 0.4904
# Época 10/30, Loss final: 0.5744
# Época 20/30, Loss final: 0.5580
# Época 30/30, Loss final: 0.5417
# Época 10/30, Loss final: 0.5973
# Época 20/30, Loss final: 0.5800
# Época 30/30, Loss final: 0.5656
# Época 10/30, Loss final: 0.5794
# Época 20/30, Loss final: 0.5532
# Época 30/30, Loss final: 0.5306
# Época 10/30, Loss final: 0.5624
# Época 20/30, Loss final: 0.5450
# Época 30/30, Loss final: 0.5218
# Época 10/30, Loss final: 0.5832
# Época 20/30, Loss final: 0.5765
# Época 30/30, Loss final: 0.5648
# Época 10/30, Loss final: 0.5779
# Época 20/30, Loss final: 0.5587
# Época 30/30, Loss final: 0.5383
# Época 10/30, Loss final: 0.5607
# Época 20/30, Loss final: 0.5064
# Época 30/30, Loss final: 0.4668
# Época 10/30, Loss final: 0.5799
# Época 20/30, Loss final: 0.5552
# Época 30/30, Loss final: 0.5326
# Época 10/30, Loss final: 0.5791
# Época 20/30, Loss final: 0.5582
# Época 30/30, Loss final: 0.5381
# Época 10/30, Loss final: 0.6018
# Época 20/30, Loss final: 0.5952
# Época 30/30, Loss final: 0.5903
# Época 10/30, Loss final: 0.5897
# Época 20/30, Loss final: 0.5784
# Época 30/30, Loss final: 0.5650
# Época 10/30, Loss final: 0.5313
# Época 20/30, Loss final: 0.4994
# Época 30/30, Loss final: 0.4740
# Época 10/30, Loss final: 0.5463
# Época 20/30, Loss final: 0.5087
# Época 30/30, Loss final: 0.4697
# Época 10/30, Loss final: 0.5686
# Época 20/30, Loss final: 0.5250
# Época 30/30, Loss final: 0.4989
# Época 10/30, Loss final: 0.5593
# Época 20/30, Loss final: 0.5247
# Época 30/30, Loss final: 0.4847
# Época 10/30, Loss final: 0.5705
# Época 20/30, Loss final: 0.5438
# Época 30/30, Loss final: 0.5104
# Época 10/30, Loss final: 0.5807
# Época 20/30, Loss final: 0.5628
# Época 30/30, Loss final: 0.5420
# Época 10/30, Loss final: 0.6007
# Época 20/30, Loss final: 0.5553
# Época 30/30, Loss final: 0.5256
# Época 10/30, Loss final: 0.5494
# Época 20/30, Loss final: 0.5263
# Época 30/30, Loss final: 0.5010
# Época 10/30, Loss final: 0.5709
# Época 20/30, Loss final: 0.5619
# Época 30/30, Loss final: 0.5505
# Época 10/30, Loss final: 0.5738
# Época 20/30, Loss final: 0.5660
# Época 30/30, Loss final: 0.5570
# Época 10/30, Loss final: 0.5465
# Época 20/30, Loss final: 0.5237
# Época 30/30, Loss final: 0.5009
# Época 10/30, Loss final: 0.5736
# Época 20/30, Loss final: 0.5495
# Época 30/30, Loss final: 0.5235
# Época 10/30, Loss final: 0.5799
# Época 20/30, Loss final: 0.5716
# Época 30/30, Loss final: 0.5564
# Época 10/30, Loss final: 0.5812
# Época 20/30, Loss final: 0.5735
# Época 30/30, Loss final: 0.5620
# Época 10/30, Loss final: 0.5324
# Época 20/30, Loss final: 0.4830
# Época 30/30, Loss final: 0.4407
# Época 10/30, Loss final: 0.5505
# Época 20/30, Loss final: 0.5201
# Época 30/30, Loss final: 0.4861
# Época 10/30, Loss final: 0.4970
# Época 20/30, Loss final: 0.4702
# Época 30/30, Loss final: 0.4457
# Época 10/30, Loss final: 0.5501
# Época 20/30, Loss final: 0.5346
# Época 30/30, Loss final: 0.5142
# Época 10/30, Loss final: 0.5550
# Época 20/30, Loss final: 0.5221
# Época 30/30, Loss final: 0.4798
# Época 10/30, Loss final: 0.5961
# Época 20/30, Loss final: 0.5808
# Época 30/30, Loss final: 0.5690
# Época 10/30, Loss final: 0.5963
# Época 20/30, Loss final: 0.5932
# Época 30/30, Loss final: 0.5904
# Época 10/30, Loss final: 0.5245
# Época 20/30, Loss final: 0.4966
# Época 30/30, Loss final: 0.4708
# Época 10/30, Loss final: 0.5887
# Época 20/30, Loss final: 0.5768
# Época 30/30, Loss final: 0.5615
# Época 10/30, Loss final: 0.5759
# Época 20/30, Loss final: 0.5440
# Época 30/30, Loss final: 0.5164
# Época 10/30, Loss final: 0.5514
# Época 20/30, Loss final: 0.5233
# Época 30/30, Loss final: 0.4956
# Época 10/30, Loss final: 0.5593
# Época 20/30, Loss final: 0.5450
# Época 30/30, Loss final: 0.5293
# Época 10/30, Loss final: 0.5532
# Época 20/30, Loss final: 0.5322
# Época 30/30, Loss final: 0.5071
# Época 10/30, Loss final: 0.5975
# Época 20/30, Loss final: 0.5902
# Época 30/30, Loss final: 0.5855
# Época 10/30, Loss final: 0.5692
# Época 20/30, Loss final: 0.5453
# Época 30/30, Loss final: 0.5060
# Época 10/30, Loss final: 0.5725
# Época 20/30, Loss final: 0.5480
# Época 30/30, Loss final: 0.5216
# Época 10/30, Loss final: 0.5347
# Época 20/30, Loss final: 0.4916
# Época 30/30, Loss final: 0.4536
# Época 10/30, Loss final: 0.5852
# Época 20/30, Loss final: 0.5790
# Época 30/30, Loss final: 0.5687
# Época 10/50, Loss final: 0.5967
# Época 20/50, Loss final: 0.5875
# Época 30/50, Loss final: 0.5689
# Época 40/50, Loss final: 0.5435
# Época 50/50, Loss final: 0.5136
# Época 10/50, Loss final: 0.5716
# Época 20/50, Loss final: 0.5454
# Época 30/50, Loss final: 0.5162
# Época 40/50, Loss final: 0.4847
# Época 50/50, Loss final: 0.4540
# Época 10/50, Loss final: 0.5173
# Época 20/50, Loss final: 0.4874
# Época 30/50, Loss final: 0.4619
# Época 40/50, Loss final: 0.4392
# Época 50/50, Loss final: 0.4189
# Época 10/50, Loss final: 0.5507
# Época 20/50, Loss final: 0.5300
# Época 30/50, Loss final: 0.5068
# Época 40/50, Loss final: 0.4822
# Época 50/50, Loss final: 0.4581
# Época 10/50, Loss final: 0.5997
# Época 20/50, Loss final: 0.5841
# Época 30/50, Loss final: 0.5705
# Época 40/50, Loss final: 0.5549
# Época 50/50, Loss final: 0.5351
# Época 10/50, Loss final: 0.5566
# Época 20/50, Loss final: 0.5324
# Época 30/50, Loss final: 0.4992
# Época 40/50, Loss final: 0.4587
# Época 50/50, Loss final: 0.4218
# Época 10/50, Loss final: 0.5587
# Época 20/50, Loss final: 0.5265
# Época 30/50, Loss final: 0.4928
# Época 40/50, Loss final: 0.4625
# Época 50/50, Loss final: 0.4361
# Época 10/50, Loss final: 0.5850
# Época 20/50, Loss final: 0.5391
# Época 30/50, Loss final: 0.4982
# Época 40/50, Loss final: 0.4556
# Época 50/50, Loss final: 0.4160
# Época 10/50, Loss final: 0.5587
# Época 20/50, Loss final: 0.5422
# Época 30/50, Loss final: 0.5204
# Época 40/50, Loss final: 0.4934
# Época 50/50, Loss final: 0.4641
# Época 10/50, Loss final: 0.5654
# Época 20/50, Loss final: 0.5236
# Época 30/50, Loss final: 0.4810
# Época 40/50, Loss final: 0.4405
# Época 50/50, Loss final: 0.4050
# Época 10/50, Loss final: 0.5613
# Época 20/50, Loss final: 0.5209
# Época 30/50, Loss final: 0.4760
# Época 40/50, Loss final: 0.4313
# Época 50/50, Loss final: 0.3932
# Época 10/50, Loss final: 0.5337
# Época 20/50, Loss final: 0.5079
# Época 30/50, Loss final: 0.4838
# Época 40/50, Loss final: 0.4612
# Época 50/50, Loss final: 0.4405
# Época 10/50, Loss final: 0.5688
# Época 20/50, Loss final: 0.5508
# Época 30/50, Loss final: 0.5250
# Época 40/50, Loss final: 0.4905
# Época 50/50, Loss final: 0.4504
# Época 10/50, Loss final: 0.5873
# Época 20/50, Loss final: 0.5766
# Época 30/50, Loss final: 0.5641
# Época 40/50, Loss final: 0.5460
# Época 50/50, Loss final: 0.5207
# Época 10/50, Loss final: 0.5843
# Época 20/50, Loss final: 0.5786
# Época 30/50, Loss final: 0.5697
# Época 40/50, Loss final: 0.5546
# Época 50/50, Loss final: 0.5326
# Época 10/50, Loss final: 0.6281
# Época 20/50, Loss final: 0.6046
# Época 30/50, Loss final: 0.5999
# Época 40/50, Loss final: 0.5974
# Época 50/50, Loss final: 0.5950
# Época 10/50, Loss final: 0.5994
# Época 20/50, Loss final: 0.5883
# Época 30/50, Loss final: 0.5648
# Época 40/50, Loss final: 0.5444
# Época 50/50, Loss final: 0.5238
# Época 10/50, Loss final: 0.5701
# Época 20/50, Loss final: 0.5414
# Época 30/50, Loss final: 0.5153
# Época 40/50, Loss final: 0.4883
# Época 50/50, Loss final: 0.4612
# Época 10/50, Loss final: 0.6018
# Época 20/50, Loss final: 0.5684
# Época 30/50, Loss final: 0.5492
# Época 40/50, Loss final: 0.5261
# Época 50/50, Loss final: 0.4959
# Época 10/50, Loss final: 0.5630
# Época 20/50, Loss final: 0.5453
# Época 30/50, Loss final: 0.5229
# Época 40/50, Loss final: 0.4971
# Época 50/50, Loss final: 0.4706
# Época 10/50, Loss final: 0.5783
# Época 20/50, Loss final: 0.5530
# Época 30/50, Loss final: 0.5260
# Época 40/50, Loss final: 0.4961
# Época 50/50, Loss final: 0.4647
# Época 10/50, Loss final: 0.5873
# Época 20/50, Loss final: 0.5822
# Época 30/50, Loss final: 0.5741
# Época 40/50, Loss final: 0.5615
# Época 50/50, Loss final: 0.5372
# Época 10/50, Loss final: 0.5714
# Época 20/50, Loss final: 0.5625
# Época 30/50, Loss final: 0.5522
# Época 40/50, Loss final: 0.5403
# Época 50/50, Loss final: 0.5252
# Época 10/50, Loss final: 0.5182
# Época 20/50, Loss final: 0.4748
# Época 30/50, Loss final: 0.4375
# Época 40/50, Loss final: 0.4051
# Época 50/50, Loss final: 0.3786
# Época 10/50, Loss final: 0.6085
# Época 20/50, Loss final: 0.5878
# Época 30/50, Loss final: 0.5741
# Época 40/50, Loss final: 0.5576
# Época 50/50, Loss final: 0.5358
# Época 10/50, Loss final: 0.5285
# Época 20/50, Loss final: 0.4962
# Época 30/50, Loss final: 0.4619
# Época 40/50, Loss final: 0.4303
# Época 50/50, Loss final: 0.4041
# Época 10/50, Loss final: 0.5939
# Época 20/50, Loss final: 0.5462
# Época 30/50, Loss final: 0.5105
# Época 40/50, Loss final: 0.4750
# Época 50/50, Loss final: 0.4407
# Época 10/50, Loss final: 0.5631
# Época 20/50, Loss final: 0.5426
# Época 30/50, Loss final: 0.5170
# Época 40/50, Loss final: 0.4905
# Época 50/50, Loss final: 0.4640
# Época 10/50, Loss final: 0.5832
# Época 20/50, Loss final: 0.5760
# Época 30/50, Loss final: 0.5630
# Época 40/50, Loss final: 0.5435
# Época 50/50, Loss final: 0.5178
# Época 10/50, Loss final: 0.5483
# Época 20/50, Loss final: 0.5255
# Época 30/50, Loss final: 0.4996
# Época 40/50, Loss final: 0.4737
# Época 50/50, Loss final: 0.4499
# Época 10/50, Loss final: 0.5132
# Época 20/50, Loss final: 0.4739
# Época 30/50, Loss final: 0.4420
# Época 40/50, Loss final: 0.4141
# Época 50/50, Loss final: 0.3900
# Época 10/50, Loss final: 0.5896
# Época 20/50, Loss final: 0.5802
# Época 30/50, Loss final: 0.5708
# Época 40/50, Loss final: 0.5587
# Época 50/50, Loss final: 0.5431
# Época 10/50, Loss final: 0.5469
# Época 20/50, Loss final: 0.5230
# Época 30/50, Loss final: 0.4987
# Época 40/50, Loss final: 0.4749
# Época 50/50, Loss final: 0.4526
# Época 10/50, Loss final: 0.6155
# Época 20/50, Loss final: 0.5940
# Época 30/50, Loss final: 0.5871
# Época 40/50, Loss final: 0.5680
# Época 50/50, Loss final: 0.5378
# Época 10/50, Loss final: 0.5592
# Época 20/50, Loss final: 0.5240
# Época 30/50, Loss final: 0.4873
# Época 40/50, Loss final: 0.4528
# Época 50/50, Loss final: 0.4215
# Época 10/50, Loss final: 0.5518
# Época 20/50, Loss final: 0.5255
# Época 30/50, Loss final: 0.4990
# Época 40/50, Loss final: 0.4734
# Época 50/50, Loss final: 0.4496
# Época 10/50, Loss final: 0.5444
# Época 20/50, Loss final: 0.5244
# Época 30/50, Loss final: 0.4999
# Época 40/50, Loss final: 0.4724
# Época 50/50, Loss final: 0.4456
# Época 10/50, Loss final: 0.5758
# Época 20/50, Loss final: 0.5548
# Época 30/50, Loss final: 0.5300
# Época 40/50, Loss final: 0.5011
# Época 50/50, Loss final: 0.4707
# Época 10/50, Loss final: 0.5868
# Época 20/50, Loss final: 0.5606
# Época 30/50, Loss final: 0.5285
# Época 40/50, Loss final: 0.4994
# Época 50/50, Loss final: 0.4683
# Época 10/50, Loss final: 0.5028
# Época 20/50, Loss final: 0.4672
# Época 30/50, Loss final: 0.4332
# Época 40/50, Loss final: 0.4020
# Época 50/50, Loss final: 0.3746
# Época 10/50, Loss final: 0.5819
# Época 20/50, Loss final: 0.5705
# Época 30/50, Loss final: 0.5583
# Época 40/50, Loss final: 0.5408
# Época 50/50, Loss final: 0.5162
# Época 10/50, Loss final: 0.5745
# Época 20/50, Loss final: 0.5545
# Época 30/50, Loss final: 0.5265
# Época 40/50, Loss final: 0.4773
# Época 50/50, Loss final: 0.4345
# Época 10/50, Loss final: 0.5721
# Época 20/50, Loss final: 0.5618
# Época 30/50, Loss final: 0.5488
# Época 40/50, Loss final: 0.5310
# Época 50/50, Loss final: 0.5028
# Época 10/50, Loss final: 0.5524
# Época 20/50, Loss final: 0.5238
# Época 30/50, Loss final: 0.4854
# Época 40/50, Loss final: 0.4431
# Época 50/50, Loss final: 0.4052
# Época 10/50, Loss final: 0.5249
# Época 20/50, Loss final: 0.4851
# Época 30/50, Loss final: 0.4443
# Época 40/50, Loss final: 0.4046
# Época 50/50, Loss final: 0.3699
# Época 10/50, Loss final: 0.5611
# Época 20/50, Loss final: 0.5369
# Época 30/50, Loss final: 0.5102
# Época 40/50, Loss final: 0.4787
# Época 50/50, Loss final: 0.4448
# Época 10/50, Loss final: 0.6096
# Época 20/50, Loss final: 0.5971
# Época 30/50, Loss final: 0.5846
# Época 40/50, Loss final: 0.5679
# Época 50/50, Loss final: 0.5463
# Época 10/50, Loss final: 0.5510
# Época 20/50, Loss final: 0.5275
# Época 30/50, Loss final: 0.5010
# Época 40/50, Loss final: 0.4750
# Época 50/50, Loss final: 0.4507
# Época 10/50, Loss final: 0.5312
# Época 20/50, Loss final: 0.5065
# Época 30/50, Loss final: 0.4802
# Época 40/50, Loss final: 0.4547
# Época 50/50, Loss final: 0.4317
# Época 10/50, Loss final: 0.5763
# Época 20/50, Loss final: 0.5656
# Época 30/50, Loss final: 0.5500
# Época 40/50, Loss final: 0.5284
# Época 50/50, Loss final: 0.5025
# Época 10/100, Loss final: 0.5587
# Época 20/100, Loss final: 0.5296
# Época 30/100, Loss final: 0.4993
# Época 40/100, Loss final: 0.4698
# Época 50/100, Loss final: 0.4429
# Época 60/100, Loss final: 0.4192
# Época 70/100, Loss final: 0.3984
# Época 80/100, Loss final: 0.3804
# Época 90/100, Loss final: 0.3645
# Época 100/100, Loss final: 0.3505
# Época 10/100, Loss final: 0.5683
# Época 20/100, Loss final: 0.5554
# Época 30/100, Loss final: 0.5343
# Época 40/100, Loss final: 0.4981
# Época 50/100, Loss final: 0.4531
# Época 60/100, Loss final: 0.4114
# Época 70/100, Loss final: 0.3786
# Época 80/100, Loss final: 0.3540
# Época 90/100, Loss final: 0.3349
# Época 100/100, Loss final: 0.3195
# Época 10/100, Loss final: 0.5965
# Época 20/100, Loss final: 0.5732
# Época 30/100, Loss final: 0.5554
# Época 40/100, Loss final: 0.5332
# Época 50/100, Loss final: 0.5043
# Época 60/100, Loss final: 0.4701
# Época 70/100, Loss final: 0.4350
# Época 80/100, Loss final: 0.4034
# Época 90/100, Loss final: 0.3769
# Época 100/100, Loss final: 0.3553
# Época 10/100, Loss final: 0.5542
# Época 20/100, Loss final: 0.5314
# Época 30/100, Loss final: 0.4999
# Época 40/100, Loss final: 0.4602
# Época 50/100, Loss final: 0.4206
# Época 60/100, Loss final: 0.3872
# Época 70/100, Loss final: 0.3616
# Época 80/100, Loss final: 0.3419
# Época 90/100, Loss final: 0.3261
# Época 100/100, Loss final: 0.3129
# Época 10/100, Loss final: 0.5751
# Época 20/100, Loss final: 0.5500
# Época 30/100, Loss final: 0.5222
# Época 40/100, Loss final: 0.4899
# Época 50/100, Loss final: 0.4562
# Época 60/100, Loss final: 0.4256
# Época 70/100, Loss final: 0.4000
# Época 80/100, Loss final: 0.3790
# Época 90/100, Loss final: 0.3618
# Época 100/100, Loss final: 0.3474
# Época 10/100, Loss final: 0.5822
# Época 20/100, Loss final: 0.5504
# Época 30/100, Loss final: 0.5179
# Época 40/100, Loss final: 0.4762
# Época 50/100, Loss final: 0.4369
# Época 60/100, Loss final: 0.4016
# Época 70/100, Loss final: 0.3727
# Época 80/100, Loss final: 0.3499
# Época 90/100, Loss final: 0.3318
# Época 100/100, Loss final: 0.3169
# Época 10/100, Loss final: 0.5524
# Época 20/100, Loss final: 0.5291
# Época 30/100, Loss final: 0.5057
# Época 40/100, Loss final: 0.4826
# Época 50/100, Loss final: 0.4606
# Época 60/100, Loss final: 0.4404
# Época 70/100, Loss final: 0.4218
# Época 80/100, Loss final: 0.4049
# Época 90/100, Loss final: 0.3895
# Época 100/100, Loss final: 0.3753
# Época 10/100, Loss final: 0.6110
# Época 20/100, Loss final: 0.5964
# Época 30/100, Loss final: 0.5907
# Época 40/100, Loss final: 0.5836
# Época 50/100, Loss final: 0.5732
# Época 60/100, Loss final: 0.5523
# Época 70/100, Loss final: 0.5186
# Época 80/100, Loss final: 0.4819
# Época 90/100, Loss final: 0.4444
# Época 100/100, Loss final: 0.4108
# Época 10/100, Loss final: 0.5660
# Época 20/100, Loss final: 0.5486
# Época 30/100, Loss final: 0.5279
# Época 40/100, Loss final: 0.5015
# Época 50/100, Loss final: 0.4697
# Época 60/100, Loss final: 0.4377
# Época 70/100, Loss final: 0.4098
# Época 80/100, Loss final: 0.3863
# Época 90/100, Loss final: 0.3666
# Época 100/100, Loss final: 0.3500
# Época 10/100, Loss final: 0.5510
# Época 20/100, Loss final: 0.5282
# Época 30/100, Loss final: 0.5025
# Época 40/100, Loss final: 0.4730
# Época 50/100, Loss final: 0.4444
# Época 60/100, Loss final: 0.4195
# Época 70/100, Loss final: 0.3986
# Época 80/100, Loss final: 0.3809
# Época 90/100, Loss final: 0.3655
# Época 100/100, Loss final: 0.3520
# Época 10/100, Loss final: 0.6072
# Época 20/100, Loss final: 0.5927
# Época 30/100, Loss final: 0.5852
# Época 40/100, Loss final: 0.5765
# Época 50/100, Loss final: 0.5640
# Época 60/100, Loss final: 0.5447
# Época 70/100, Loss final: 0.5186
# Época 80/100, Loss final: 0.4879
# Época 90/100, Loss final: 0.4576
# Época 100/100, Loss final: 0.4311
# Época 10/100, Loss final: 0.5100
# Época 20/100, Loss final: 0.4789
# Época 30/100, Loss final: 0.4500
# Época 40/100, Loss final: 0.4246
# Época 50/100, Loss final: 0.4030
# Época 60/100, Loss final: 0.3847
# Época 70/100, Loss final: 0.3690
# Época 80/100, Loss final: 0.3554
# Época 90/100, Loss final: 0.3434
# Época 100/100, Loss final: 0.3325
# Época 10/100, Loss final: 0.5754
# Época 20/100, Loss final: 0.5432
# Época 30/100, Loss final: 0.5067
# Época 40/100, Loss final: 0.4651
# Época 50/100, Loss final: 0.4370
# Época 60/100, Loss final: 0.4148
# Época 70/100, Loss final: 0.3959
# Época 80/100, Loss final: 0.3795
# Época 90/100, Loss final: 0.3649
# Época 100/100, Loss final: 0.3520
# Época 10/100, Loss final: 0.5826
# Época 20/100, Loss final: 0.5766
# Época 30/100, Loss final: 0.5642
# Época 40/100, Loss final: 0.5463
# Época 50/100, Loss final: 0.5222
# Época 60/100, Loss final: 0.4912
# Época 70/100, Loss final: 0.4575
# Época 80/100, Loss final: 0.4259
# Época 90/100, Loss final: 0.3968
# Época 100/100, Loss final: 0.3710
# Época 10/100, Loss final: 0.5797
# Época 20/100, Loss final: 0.5703
# Época 30/100, Loss final: 0.5565
# Época 40/100, Loss final: 0.5363
# Época 50/100, Loss final: 0.5110
# Época 60/100, Loss final: 0.4853
# Época 70/100, Loss final: 0.4614
# Época 80/100, Loss final: 0.4397
# Época 90/100, Loss final: 0.4201
# Época 100/100, Loss final: 0.4025
# Época 10/100, Loss final: 0.5806
# Época 20/100, Loss final: 0.5667
# Época 30/100, Loss final: 0.5473
# Época 40/100, Loss final: 0.5210
# Época 50/100, Loss final: 0.4893
# Época 60/100, Loss final: 0.4550
# Época 70/100, Loss final: 0.4220
# Época 80/100, Loss final: 0.3926
# Época 90/100, Loss final: 0.3677
# Época 100/100, Loss final: 0.3472
# Época 10/100, Loss final: 0.5822
# Época 20/100, Loss final: 0.5650
# Época 30/100, Loss final: 0.5469
# Época 40/100, Loss final: 0.5233
# Época 50/100, Loss final: 0.4948
# Época 60/100, Loss final: 0.4645
# Época 70/100, Loss final: 0.4364
# Época 80/100, Loss final: 0.4120
# Época 90/100, Loss final: 0.3912
# Época 100/100, Loss final: 0.3735
# Época 10/100, Loss final: 0.5393
# Época 20/100, Loss final: 0.5000
# Época 30/100, Loss final: 0.4638
# Época 40/100, Loss final: 0.4310
# Época 50/100, Loss final: 0.4032
# Época 60/100, Loss final: 0.3802
# Época 70/100, Loss final: 0.3614
# Época 80/100, Loss final: 0.3458
# Época 90/100, Loss final: 0.3326
# Época 100/100, Loss final: 0.3211
# Época 10/100, Loss final: 0.5715
# Época 20/100, Loss final: 0.5503
# Época 30/100, Loss final: 0.5210
# Época 40/100, Loss final: 0.4848
# Época 50/100, Loss final: 0.4477
# Época 60/100, Loss final: 0.4126
# Época 70/100, Loss final: 0.3811
# Época 80/100, Loss final: 0.3543
# Época 90/100, Loss final: 0.3325
# Época 100/100, Loss final: 0.3148
# Época 10/100, Loss final: 0.5421
# Época 20/100, Loss final: 0.5076
# Época 30/100, Loss final: 0.4739
# Época 40/100, Loss final: 0.4410
# Época 50/100, Loss final: 0.4110
# Época 60/100, Loss final: 0.3852
# Época 70/100, Loss final: 0.3636
# Época 80/100, Loss final: 0.3457
# Época 90/100, Loss final: 0.3306
# Época 100/100, Loss final: 0.3178
# Época 10/100, Loss final: 0.5775
# Época 20/100, Loss final: 0.5581
# Época 30/100, Loss final: 0.5332
# Época 40/100, Loss final: 0.5023
# Época 50/100, Loss final: 0.4666
# Época 60/100, Loss final: 0.4295
# Época 70/100, Loss final: 0.3967
# Época 80/100, Loss final: 0.3704
# Época 90/100, Loss final: 0.3497
# Época 100/100, Loss final: 0.3329
# Época 10/100, Loss final: 0.5625
# Época 20/100, Loss final: 0.5400
# Época 30/100, Loss final: 0.5150
# Época 40/100, Loss final: 0.4816
# Época 50/100, Loss final: 0.4427
# Época 60/100, Loss final: 0.4077
# Época 70/100, Loss final: 0.3785
# Época 80/100, Loss final: 0.3549
# Época 90/100, Loss final: 0.3359
# Época 100/100, Loss final: 0.3203
# Época 10/100, Loss final: 0.5726
# Época 20/100, Loss final: 0.5479
# Época 30/100, Loss final: 0.5185
# Época 40/100, Loss final: 0.4855
# Época 50/100, Loss final: 0.4575
# Época 60/100, Loss final: 0.4337
# Época 70/100, Loss final: 0.4121
# Época 80/100, Loss final: 0.3903
# Época 90/100, Loss final: 0.3685
# Época 100/100, Loss final: 0.3501
# Época 10/100, Loss final: 0.5561
# Época 20/100, Loss final: 0.5368
# Época 30/100, Loss final: 0.5138
# Época 40/100, Loss final: 0.4861
# Época 50/100, Loss final: 0.4560
# Época 60/100, Loss final: 0.4275
# Época 70/100, Loss final: 0.4026
# Época 80/100, Loss final: 0.3816
# Época 90/100, Loss final: 0.3640
# Época 100/100, Loss final: 0.3491
# Época 10/100, Loss final: 0.5953
# Época 20/100, Loss final: 0.5859
# Época 30/100, Loss final: 0.5775
# Época 40/100, Loss final: 0.5665
# Época 50/100, Loss final: 0.5518
# Época 60/100, Loss final: 0.5324
# Época 70/100, Loss final: 0.5056
# Época 80/100, Loss final: 0.4756
# Época 90/100, Loss final: 0.4474
# Época 100/100, Loss final: 0.4168
# Época 10/100, Loss final: 0.5738
# Época 20/100, Loss final: 0.5536
# Época 30/100, Loss final: 0.5254
# Época 40/100, Loss final: 0.4875
# Época 50/100, Loss final: 0.4478
# Época 60/100, Loss final: 0.4118
# Época 70/100, Loss final: 0.3811
# Época 80/100, Loss final: 0.3556
# Época 90/100, Loss final: 0.3349
# Época 100/100, Loss final: 0.3179
# Época 10/100, Loss final: 0.5575
# Época 20/100, Loss final: 0.5410
# Época 30/100, Loss final: 0.5218
# Época 40/100, Loss final: 0.4997
# Época 50/100, Loss final: 0.4773
# Época 60/100, Loss final: 0.4564
# Época 70/100, Loss final: 0.4374
# Época 80/100, Loss final: 0.4204
# Época 90/100, Loss final: 0.4051
# Época 100/100, Loss final: 0.3912
# Época 10/100, Loss final: 0.5401
# Época 20/100, Loss final: 0.5112
# Época 30/100, Loss final: 0.4803
# Época 40/100, Loss final: 0.4544
# Época 50/100, Loss final: 0.4321
# Época 60/100, Loss final: 0.4124
# Época 70/100, Loss final: 0.3950
# Época 80/100, Loss final: 0.3794
# Época 90/100, Loss final: 0.3656
# Época 100/100, Loss final: 0.3531
# Época 10/100, Loss final: 0.5660
# Época 20/100, Loss final: 0.5339
# Época 30/100, Loss final: 0.5013
# Época 40/100, Loss final: 0.4640
# Época 50/100, Loss final: 0.4276
# Época 60/100, Loss final: 0.3956
# Época 70/100, Loss final: 0.3690
# Época 80/100, Loss final: 0.3473
# Época 90/100, Loss final: 0.3297
# Época 100/100, Loss final: 0.3152
# Época 10/100, Loss final: 0.6009
# Época 20/100, Loss final: 0.5720
# Época 30/100, Loss final: 0.5509
# Época 40/100, Loss final: 0.5224
# Época 50/100, Loss final: 0.4847
# Época 60/100, Loss final: 0.4471
# Época 70/100, Loss final: 0.4134
# Época 80/100, Loss final: 0.3847
# Época 90/100, Loss final: 0.3604
# Época 100/100, Loss final: 0.3397
# Época 10/100, Loss final: 0.5572
# Época 20/100, Loss final: 0.5387
# Época 30/100, Loss final: 0.5147
# Época 40/100, Loss final: 0.4881
# Época 50/100, Loss final: 0.4633
# Época 60/100, Loss final: 0.4415
# Época 70/100, Loss final: 0.4220
# Época 80/100, Loss final: 0.4044
# Época 90/100, Loss final: 0.3882
# Época 100/100, Loss final: 0.3729
# Época 10/100, Loss final: 0.5730
# Época 20/100, Loss final: 0.5589
# Época 30/100, Loss final: 0.5430
# Época 40/100, Loss final: 0.5193
# Época 50/100, Loss final: 0.4880
# Época 60/100, Loss final: 0.4523
# Época 70/100, Loss final: 0.4184
# Época 80/100, Loss final: 0.3885
# Época 90/100, Loss final: 0.3619
# Época 100/100, Loss final: 0.3390
# Época 10/100, Loss final: 0.5563
# Época 20/100, Loss final: 0.5321
# Época 30/100, Loss final: 0.5088
# Época 40/100, Loss final: 0.4824
# Época 50/100, Loss final: 0.4541
# Época 60/100, Loss final: 0.4273
# Época 70/100, Loss final: 0.4045
# Época 80/100, Loss final: 0.3858
# Época 90/100, Loss final: 0.3701
# Época 100/100, Loss final: 0.3565
# Época 10/100, Loss final: 0.5558
# Época 20/100, Loss final: 0.4968
# Época 30/100, Loss final: 0.4674
# Época 40/100, Loss final: 0.4422
# Época 50/100, Loss final: 0.4201
# Época 60/100, Loss final: 0.4008
# Época 70/100, Loss final: 0.3839
# Época 80/100, Loss final: 0.3689
# Época 90/100, Loss final: 0.3556
# Época 100/100, Loss final: 0.3435
# Época 10/100, Loss final: 0.5878
# Época 20/100, Loss final: 0.5819
# Época 30/100, Loss final: 0.5671
# Época 40/100, Loss final: 0.5416
# Época 50/100, Loss final: 0.5086
# Época 60/100, Loss final: 0.4806
# Época 70/100, Loss final: 0.4572
# Época 80/100, Loss final: 0.4370
# Época 90/100, Loss final: 0.4192
# Época 100/100, Loss final: 0.4034
# Época 10/100, Loss final: 0.5834
# Época 20/100, Loss final: 0.5762
# Época 30/100, Loss final: 0.5674
# Época 40/100, Loss final: 0.5518
# Época 50/100, Loss final: 0.5262
# Época 60/100, Loss final: 0.4934
# Época 70/100, Loss final: 0.4602
# Época 80/100, Loss final: 0.4286
# Época 90/100, Loss final: 0.3998
# Época 100/100, Loss final: 0.3742
# Época 10/100, Loss final: 0.5876
# Época 20/100, Loss final: 0.5613
# Época 30/100, Loss final: 0.5454
# Época 40/100, Loss final: 0.5224
# Época 50/100, Loss final: 0.4900
# Época 60/100, Loss final: 0.4487
# Época 70/100, Loss final: 0.4056
# Época 80/100, Loss final: 0.3702
# Época 90/100, Loss final: 0.3432
# Época 100/100, Loss final: 0.3224
# Época 10/100, Loss final: 0.6039
# Época 20/100, Loss final: 0.5944
# Época 30/100, Loss final: 0.5903
# Época 40/100, Loss final: 0.5838
# Época 50/100, Loss final: 0.5573
# Época 60/100, Loss final: 0.5283
# Época 70/100, Loss final: 0.4990
# Época 80/100, Loss final: 0.4722
# Época 90/100, Loss final: 0.4481
# Época 100/100, Loss final: 0.4266
# Época 10/100, Loss final: 0.5749
# Época 20/100, Loss final: 0.5368
# Época 30/100, Loss final: 0.5027
# Época 40/100, Loss final: 0.4670
# Época 50/100, Loss final: 0.4342
# Época 60/100, Loss final: 0.4062
# Época 70/100, Loss final: 0.3832
# Época 80/100, Loss final: 0.3643
# Época 90/100, Loss final: 0.3486
# Época 100/100, Loss final: 0.3353
# Época 10/100, Loss final: 0.6126
# Época 20/100, Loss final: 0.5782
# Época 30/100, Loss final: 0.5590
# Época 40/100, Loss final: 0.5341
# Época 50/100, Loss final: 0.5020
# Época 60/100, Loss final: 0.4660
# Época 70/100, Loss final: 0.4311
# Época 80/100, Loss final: 0.4007
# Época 90/100, Loss final: 0.3758
# Época 100/100, Loss final: 0.3556
# Época 10/100, Loss final: 0.5762
# Época 20/100, Loss final: 0.5703
# Época 30/100, Loss final: 0.5618
# Época 40/100, Loss final: 0.5485
# Época 50/100, Loss final: 0.5287
# Época 60/100, Loss final: 0.5036
# Época 70/100, Loss final: 0.4765
# Época 80/100, Loss final: 0.4493
# Época 90/100, Loss final: 0.4234
# Época 100/100, Loss final: 0.3996
# Época 10/100, Loss final: 0.5344
# Época 20/100, Loss final: 0.5107
# Época 30/100, Loss final: 0.4847
# Época 40/100, Loss final: 0.4626
# Época 50/100, Loss final: 0.4423
# Época 60/100, Loss final: 0.4236
# Época 70/100, Loss final: 0.4066
# Época 80/100, Loss final: 0.3913
# Época 90/100, Loss final: 0.3777
# Época 100/100, Loss final: 0.3654
# Época 10/100, Loss final: 0.5529
# Época 20/100, Loss final: 0.5319
# Época 30/100, Loss final: 0.5084
# Época 40/100, Loss final: 0.4848
# Época 50/100, Loss final: 0.4625
# Época 60/100, Loss final: 0.4421
# Época 70/100, Loss final: 0.4238
# Época 80/100, Loss final: 0.4073
# Época 90/100, Loss final: 0.3924
# Época 100/100, Loss final: 0.3790
# Época 10/100, Loss final: 0.5862
# Época 20/100, Loss final: 0.5724
# Época 30/100, Loss final: 0.5603
# Época 40/100, Loss final: 0.5440
# Época 50/100, Loss final: 0.5208
# Época 60/100, Loss final: 0.4902
# Época 70/100, Loss final: 0.4543
# Época 80/100, Loss final: 0.4203
# Época 90/100, Loss final: 0.3903
# Época 100/100, Loss final: 0.3642
# Época 10/100, Loss final: 0.5776
# Época 20/100, Loss final: 0.5649
# Época 30/100, Loss final: 0.5403
# Época 40/100, Loss final: 0.5078
# Época 50/100, Loss final: 0.4691
# Época 60/100, Loss final: 0.4278
# Época 70/100, Loss final: 0.3914
# Época 80/100, Loss final: 0.3630
# Época 90/100, Loss final: 0.3416
# Época 100/100, Loss final: 0.3248
# Época 10/100, Loss final: 0.5929
# Época 20/100, Loss final: 0.5892
# Época 30/100, Loss final: 0.5857
# Época 40/100, Loss final: 0.5818
# Época 50/100, Loss final: 0.5771
# Época 60/100, Loss final: 0.5712
# Época 70/100, Loss final: 0.5639
# Época 80/100, Loss final: 0.5540
# Época 90/100, Loss final: 0.5388
# Época 100/100, Loss final: 0.5167
# Época 10/100, Loss final: 0.5595
# Época 20/100, Loss final: 0.5364
# Época 30/100, Loss final: 0.5100
# Época 40/100, Loss final: 0.4840
# Época 50/100, Loss final: 0.4597
# Época 60/100, Loss final: 0.4375
# Época 70/100, Loss final: 0.4173
# Época 80/100, Loss final: 0.3989
# Época 90/100, Loss final: 0.3822
# Época 100/100, Loss final: 0.3669
# Época 10/100, Loss final: 0.5407
# Época 20/100, Loss final: 0.5119
# Época 30/100, Loss final: 0.4842
# Época 40/100, Loss final: 0.4580
# Época 50/100, Loss final: 0.4338
# Época 60/100, Loss final: 0.4115
# Época 70/100, Loss final: 0.3911
# Época 80/100, Loss final: 0.3724
# Época 90/100, Loss final: 0.3549
# Época 100/100, Loss final: 0.3383
# Época 10/100, Loss final: 0.5930
# Época 20/100, Loss final: 0.5841
# Época 30/100, Loss final: 0.5719
# Época 40/100, Loss final: 0.5526
# Época 50/100, Loss final: 0.5284
# Época 60/100, Loss final: 0.4973
# Época 70/100, Loss final: 0.4612
# Época 80/100, Loss final: 0.4244
# Época 90/100, Loss final: 0.3912
# Época 100/100, Loss final: 0.3639
# Época 10/100, Loss final: 0.5435
# Época 20/100, Loss final: 0.5027
# Época 30/100, Loss final: 0.4545
# Época 40/100, Loss final: 0.4107
# Época 50/100, Loss final: 0.3778
# Época 60/100, Loss final: 0.3532
# Época 70/100, Loss final: 0.3341
# Época 80/100, Loss final: 0.3187
# Época 90/100, Loss final: 0.3060
# Época 100/100, Loss final: 0.3187
#         count      mean       std       min       25%       50%       75%  \
# Épocas
# 30       50.0  0.665205  0.018182  0.657534  0.657534  0.657534  0.657534
# 50       50.0  0.699726  0.036907  0.657534  0.657534  0.698630  0.736301
# 100      50.0  0.739178  0.012969  0.657534  0.739726  0.739726  0.739726
#
#              max
# Épocas
# 30      0.726027
# 50      0.753425
# 100     0.767123
